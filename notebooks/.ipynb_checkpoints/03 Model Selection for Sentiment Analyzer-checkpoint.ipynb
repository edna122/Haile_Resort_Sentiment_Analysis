# %% [markdown]
# ## Importing all dependencies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re,string,unicodedata
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,f1_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk.corpus import wordnet
import re
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading of Data

# %%
#Load data
df = pd.read_csv(r'C:\Users\Edna\Documents\GitHub\Haile_Resort_Sentiment_Analysis\data\processed\Haile_and_kaggledata.csv')
df.head()
# Out:
#    reviews.rating                                      reviews.title  \
# 0               5                                        Exceptional
# 1               5  My stay at the Haile Grand Addis was a truly m...
# 2               5  It was amazing! Great location and friendly st...
# 3               5  You, feel, welcomed, with great smiles. Their ...
# 4               5  I had the best time, staying at this hotel, ev...
#
#                                         reviews.text         city  \
# 0  very courteous and friendly service nice spa f...  Addis Ababa
# 1  my stay at the haile grand addis hotel was not...  Addis Ababa
# 2  our stay at haile grand was more than a stay i...  Addis Ababa
# 3  beautiful very modern and still charming of ol...  Addis Ababa
# 4  the hotel is beautiful from decoration to layo...  Addis Ababa
#
#    Sentiment_score Sentiment
# 0           0.9268  Positive
# 1           0.9769  Positive
# 2           0.9709  Positive
# 3           0.9659  Positive
# ...

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
#Customize stopword as per data
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
new_stopwords = ["would","shall","could","might"]
stop_words.extend(new_stopwords)
stop_words.remove("not")
stop_words=set(stop_words)
print(stop_words)
# Out:
# {'needn', 's', 'for', 'other', 'weren', "wasn't", 'ourselves', 'just', 'had', "you'll", 'most', 'only', 'when', "hasn't", 'her', 'very', 'off', 'haven', 'my', 't', 'should', 'here', 'in', "mightn't", 'until', 'shouldn', 'your', 'which', 'can', 'might', "wouldn't", 'aren', 'him', "won't", 'but', 'about', 'o', 'his', 'are', 'against', 'into', 'has', "it's", 'y', 'at', "don't", 'ma', 'mustn', 'up', 'now', 'been', 'or', 'have', 'over', "doesn't", 'those', 'between', 'down', 'ain', 'while', 'couldn', 'don', 'll', 've', 'below', 'whom', 'mightn', 'didn', 'himself', 'more', "aren't", 'it', 'through', 'shall', 'them', 'after', 'under', 'be', 'do', 'once', 'own', 'ours', 'who', 'out', 'wasn', 'any', "you're", "she's", 'on', 'm', 'some', 'during', 'he', 'what', 'an', 'she', 'so', 'because', 'itself', 'nor', 'themselves', 'too', "haven't", 'does', 'their', 're', 'wouldn', 'will', 'd', 'you', 'where', 'me', 'yours', "shan't", "that'll", 'they', 'as', 'from', 'am', 'a', 'again', "weren't", 'its',
# ...

# %%
'''-----------------------------Data Cleaning and Preprocessing pipeline----------------------------------'''

#Removing special character
def remove_special_character(content):
    return re.sub('\W+',' ', content )#re.sub('\[[^&@#!]]*\]', '', content)

# Removing URL's
def remove_url(content):
    return re.sub(r'http\S+', '', content)

#Removing the stopwords from text
def remove_stopwords(content):
    clean_data = []
    for i in content.split():
        if i.strip().lower() not in stop_words and i.strip().lower().isalpha():
            clean_data.append(i.strip().lower())
    return " ".join(clean_data)

# Expansion of english contractions
def contraction_expansion(content):
    content = re.sub(r"won\'t", "would not", content)
    content = re.sub(r"can\'t", "can not", content)
    content = re.sub(r"don\'t", "do not", content)
    content = re.sub(r"shouldn\'t", "should not", content)
    content = re.sub(r"needn\'t", "need not", content)
    content = re.sub(r"hasn\'t", "has not", content)
    content = re.sub(r"haven\'t", "have not", content)
    content = re.sub(r"weren\'t", "were not", content)
    content = re.sub(r"mightn\'t", "might not", content)
    content = re.sub(r"didn\'t", "did not", content)
    content = re.sub(r"n\'t", " not", content)
    content = re.sub(r"\'re", " are", content)
    content = re.sub(r"\'s", " is", content)
    content = re.sub(r"\'d", " would", content)
    content = re.sub(r"\'ll", " will", content)
    content = re.sub(r"\'t", " not", content)
    content = re.sub(r"\'ve", " have", content)
    content = re.sub(r"\'m", " am", content)
    return content

#Data preprocessing
def data_cleaning(content):
    content = contraction_expansion(content)
    content = remove_special_character(content)
    content = remove_url(content)
    
    content = remove_stopwords(content)    
    return content

# %%
#Data cleaning
df['Reviews_clean']=df['reviews.text'].apply(data_cleaning)
df[['Reviews_clean','reviews.text']].head(5)
# Out:
#                                        Reviews_clean  \
# 0  courteous friendly service nice spa facilities...
# 1  stay haile grand addis hotel nothing short exc...
# 2  stay haile grand stay experience staff friendl...
# 3  beautiful modern still charming old building s...
# 4  hotel beautiful decoration layout rooms lighti...
#
#                                         reviews.text
# 0  very courteous and friendly service nice spa f...
# 1  my stay at the haile grand addis hotel was not...
# 2  our stay at haile grand was more than a stay i...
# 3  beautiful very modern and still charming of ol...
# 4  the hotel is beautiful from decoration to layo...

# %%
# Mapping sentiment to numerical labels
label_mapping = {
    'Positive': 1,
    'Negative': 0,
    'Neutral': 2
}
df['Label'] = df['Sentiment'].map(label_mapping)

df['Label'].value_counts()
# Out:
# Label
# 1    9191
# 0    1240
# 2     187
# Name: count, dtype: int64

# %%
#Importing dependencies for feature engineering 
import sys
import os
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from prettytable import PrettyTable
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Lemmatization

# %%
# lemmatization of word 
class LemmaTokenizer(object):
    def __init__(self):
        self.wordnetlemma = WordNetLemmatizer()
    def __call__(self, reviews):
        return [self.wordnetlemma.lemmatize(word) for word in word_tokenize(reviews)]

# %% [markdown]
# ## Vectorization with Count Vectorizer and TDIDF Vectorizer with unigram, bigram and trigram

# %%
train,test=train_test_split(df,test_size=.2,random_state=42, shuffle=True)
#countvect = CountVectorizer(analyzer = "word", tokenizer = LemmaTokenizer(), ngram_range=(1,3), min_df=10,max_features=5000)
tfidfvect = TfidfVectorizer(analyzer = "word", tokenizer = LemmaTokenizer(), ngram_range=(1,3),min_df=10,max_features=1000)
#x_train_count = countvect.fit_transform(train['Reviews_clean']).toarray()
#x_test_count = countvect.transform(test['Reviews_clean']).toarray()
x_train_tfidf = tfidfvect.fit_transform(train['Reviews_clean']).toarray()
x_test_tfidf = tfidfvect.transform(test['Reviews_clean']).toarray()

y_train = train['Label']
y_test = test['Label']

# %% [markdown]
# ## Feature Selection with Chi squared

# %%
from sklearn.feature_selection import chi2
import numpy as np
N = 20
Number = 1
featureselection = PrettyTable(["Unigram", "Bigram","Trigram"])
for category in train['Label'].unique():
    features_chi2 = chi2(x_train_tfidf, train['Label'] == category)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidfvect.get_feature_names_out())[indices] 
    unigrams = [x for x in feature_names if len(x.split(' ')) == 1]
    bigrams = [x for x in feature_names if len(x.split(' ')) == 2]
    trigrams = [x for x in feature_names if len(x.split(' ')) == 3]
    print("%s. %s :" % (Number,category))
    print("\t# Unigrams :\n\t. %s" %('\n\t. '.join(unigrams[-N:])))
    print("\t# Bigrams :\n\t. %s" %('\n\t. '.join(bigrams[-N:])))
    print("\t# Trigrams :\n\t. %s" %('\n\t. '.join(trigrams[-N:])))
    Number += 1
# Out:
# 1. 1 :
# 	# Unigrams :
# 	. never
# 	. door
# 	. toilet
# 	. towel
# 	. charged
# 	. sheet
# 	. great
# 	. smelled
# 	. said
# 	. carpet
# 	. apologize
# 	. wall
# 	. smell
# 	. broken
# 	. sorry
# 	. told
# 	. poor
# 	. bad
# 	. not
# 	. dirty
# 	# Bigrams :
# 	. hope see
# 	. clean comfortable
# 	. friendly staff
# 	. front desk
# 	. definitely stay
# 	. highly recommend
# 	. walking distance
# 	. give u
# 	. look forward
# 	. room clean
# 	. friendly helpful
# 	. staff friendly
# 	. enjoyed stay
# 	. sorry hear
# 	. hot water
# 	. u another
# 	. room not
# 	. not even
# 	. not stay
# 	. not work
# 	# Trigrams :
# 	. taking time share
# 	. thank taking time
# 	. thank much taking
# 	. much taking time
# 	. stayed one night
# 	. hilton garden inn
# 	. hope welcome back
# 	. time write review
# 	. taking time write
# 	. happy hear enjoyed
# 	. hope see soon
# 	. glad enjoyed stay
# 	. hear enjoyed stay
# 	. room clean comfortable
# 	. enjoyed stay u
# 	. within walking distance
# ...

# %% [markdown]
# ## Model Selection

# %%
# Import prerequisite libraries
import sys
import numpy as np
import scipy as sp
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Logistic Regression Model

# %%
model_1=LogisticRegression()

# %% [markdown]
# ## Training of Logistic Regression Model

# %%
model_1.fit(x_train_tfidf,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Evaluation on Test and Train dataset

# %%
from sklearn.metrics import precision_score, roc_auc_score, f1_score

# Calculate Precision, AUC, and F1 scores for Logistic Regression

# Precision score on training data
print("Precision Score on training dataset for Logistic Regression: %s" % precision_score(y_train, model_1.predict(x_train_tfidf), average='micro'))

# AUC score on training data - Use 'ovr' for multiclass AUC (one-vs-rest)
print("AUC Score on training dataset for Logistic Regression: %s" % roc_auc_score(y_train, model_1.predict_proba(x_train_tfidf), multi_class='ovr', average='macro'))

# F1 score on training data
f1_score_train_1 = f1_score(y_train, model_1.predict(x_train_tfidf), average="weighted")
print("F1 Score on training dataset for Logistic Regression: %s" % f1_score_train_1)

# Precision score on test data
print("Precision Score on test dataset for Logistic Regression: %s" % precision_score(y_test, model_1.predict(x_test_tfidf), average='micro'))

# AUC score on test data - Use 'ovr' for multiclass AUC (one-vs-rest)
print("AUC Score on test dataset for Logistic Regression: %s" % roc_auc_score(y_test, model_1.predict_proba(x_test_tfidf), multi_class='ovr', average='macro'))

# F1 score on test data
f1_score_1 = f1_score(y_test, model_1.predict(x_test_tfidf), average="weighted")
print("F1 Score on test dataset for Logistic Regression: %s" % f1_score_1)
# Out:
# Precision Score on training dataset for Logistic Regression: 0.9398398869790441
# AUC Score on training dataset for Logistic Regression: 0.9777505293182535
# F1 Score on training dataset for Logistic Regression: 0.9292083954457455
# Precision Score on test dataset for Logistic Regression: 0.9199623352165726
# AUC Score on test dataset for Logistic Regression: 0.9242214317559864
# F1 Score on test dataset for Logistic Regression: 0.9099391274977436

# %% [markdown]
# ## Decision Tree Classifier

# %%
model_2 = Pipeline(
    steps=[
        #("classifier", DecisionTreeClassifier(criterion='gini', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=None, random_state=None, max_leaf_nodes=None, min_impurity_decrease=0.0, class_weight=None, ccp_alpha=0.0)),
    ("classifier", DecisionTreeClassifier())
    ]
)

# %% [markdown]
# ## Training of Decision Tree Classifier

# %%
model_2.fit(x_train_tfidf,y_train)
# Out:
# Pipeline(steps=[('classifier', DecisionTreeClassifier())])

# %% [markdown]
# ## Evaluation on test data and training data of Decision Tree Classifier

# %%
from sklearn.metrics import precision_score, roc_auc_score, f1_score

# Precision score on training data
print("Precision Score on training dataset for Decision Tree Classifier: %s" % precision_score(y_train, model_2.predict(x_train_tfidf), average='micro'))

# AUC score on training data - Use 'ovr' for multiclass AUC (One-vs-Rest)
print("AUC Score on training dataset for Decision Tree Classifier: %s" % roc_auc_score(y_train, model_2.predict_proba(x_train_tfidf), multi_class='ovr', average='macro'))

# F1 score on training data
f1_score_train_2 = f1_score(y_train, model_2.predict(x_train_tfidf), average="weighted")
print("F1 Score on training dataset for Decision Tree Classifier: %s" % f1_score_train_2)

# Precision score on test data
print("Precision Score on test dataset for Decision Tree Classifier: %s" % precision_score(y_test, model_2.predict(x_test_tfidf), average='micro'))

# AUC score on test data - Use 'ovr' for multiclass AUC (One-vs-Rest)
print("AUC Score on test dataset for Decision Tree Classifier: %s" % roc_auc_score(y_test, model_2.predict_proba(x_test_tfidf), multi_class='ovr', average='macro'))

# F1 score on test data
f1_score_2 = f1_score(y_test, model_2.predict(x_test_tfidf), average="weighted")
print("F1 Score on test dataset for Decision Tree Classifier: %s" % f1_score_2)
# Out:
# Precision Score on training dataset for Decision Tree Classifier: 0.9963503649635036
# AUC Score on training dataset for Decision Tree Classifier: 0.9997931920534658
# F1 Score on training dataset for Decision Tree Classifier: 0.9962457868850697
# Precision Score on test dataset for Decision Tree Classifier: 0.8611111111111112
# AUC Score on test dataset for Decision Tree Classifier: 0.6762492152172186
# F1 Score on test dataset for Decision Tree Classifier: 0.859628615118276

# %% [markdown]
# # Decision Tree Classifier with max depth 11 to fix overfit

# %%
model_3 = Pipeline(
    steps=[
        ("classifier", DecisionTreeClassifier( criterion='gini', max_depth=11, min_samples_split=2, min_samples_leaf=1)),
    ]
)

# %%
model_3.fit(x_train_tfidf,y_train)
# Out:
# Pipeline(steps=[('classifier', DecisionTreeClassifier(max_depth=11))])

# %%
from sklearn.metrics import precision_score, roc_auc_score, f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split


model_3 = DecisionTreeClassifier(max_depth=5, random_state=42)  

# Fit the model
model_3.fit(x_train_tfidf, y_train)

# Train set metrics
print("Precision Score on training dataset for Decision Tree Classifier: %s" % precision_score(y_train, model_3.predict(x_train_tfidf), average='micro'))
print("AUC Score on training dataset for Decision Tree Classifier: %s" % roc_auc_score(y_train, model_3.predict_proba(x_train_tfidf), multi_class='ovr', average='macro'))
f1_score_train_3 = f1_score(y_train, model_3.predict(x_train_tfidf), average="weighted")
print("F1 Score on training dataset for Decision Tree Classifier: %s" % f1_score_train_3)

# Test set metrics
print("Precision Score on test dataset for Decision Tree Classifier: %s" % precision_score(y_test, model_3.predict(x_test_tfidf), average='micro'))
print("AUC Score on test dataset for Decision Tree Classifier: %s" % roc_auc_score(y_test, model_3.predict_proba(x_test_tfidf), multi_class='ovr', average='macro'))
f1_score_3 = f1_score(y_test, model_3.predict(x_test_tfidf), average="weighted")
print("F1 Score on test dataset for Decision Tree Classifier: %s" % f1_score_3)
# Out:
# Precision Score on training dataset for Decision Tree Classifier: 0.8820343772074406
# AUC Score on training dataset for Decision Tree Classifier: 0.7753726893159261
# F1 Score on training dataset for Decision Tree Classifier: 0.8420053815651203
# Precision Score on test dataset for Decision Tree Classifier: 0.8728813559322034
# AUC Score on test dataset for Decision Tree Classifier: 0.7272662562020221
# F1 Score on test dataset for Decision Tree Classifier: 0.8302746350362037

# %% [markdown]
# ## Random Forest Classifier

# %%
model_4 = Pipeline(
    steps=[
        #("classifier", RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=15, min_samples_split=3, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None))
    ("classifier", RandomForestClassifier())]
)

# %% [markdown]
# ## Training of Random Forest Classifier

# %%
model_4.fit(x_train_tfidf,y_train)
# Out:
# Pipeline(steps=[('classifier', RandomForestClassifier())])

# %% [markdown]
# ## Evaluation on test data and training data of Random Forest Classifier

# %%
from sklearn.metrics import precision_score, roc_auc_score, f1_score
from sklearn.ensemble import RandomForestClassifier


model_4 = RandomForestClassifier(n_estimators=100, random_state=42)  

# Fit the model
model_4.fit(x_train_tfidf, y_train)

# Train set metrics
print("Precision Score on training dataset for Random Forest Classifier: %s" % precision_score(y_train, model_4.predict(x_train_tfidf), average='micro'))
print("AUC Score on training dataset for Random Forest Classifier: %s" % roc_auc_score(y_train, model_4.predict_proba(x_train_tfidf), multi_class='ovr', average='macro'))
f1_score_train_4 = f1_score(y_train, model_4.predict(x_train_tfidf), average="weighted")
print("F1 Score on training dataset for Random Forest Classifier: %s" % f1_score_train_4)

# Test set metrics
print("Precision Score on test dataset for Random Forest Classifier: %s" % precision_score(y_test, model_4.predict(x_test_tfidf), average='micro'))
print("AUC Score on test dataset for Random Forest Classifier: %s" % roc_auc_score(y_test, model_4.predict_proba(x_test_tfidf), multi_class='ovr', average='macro'))
f1_score_4 = f1_score(y_test, model_4.predict(x_test_tfidf), average="weighted")
print("F1 Score on test dataset for Random Forest Classifier: %s" % f1_score_4)
# Out:
# Precision Score on training dataset for Random Forest Classifier: 0.9963503649635036
# AUC Score on training dataset for Random Forest Classifier: 0.9997856375857537
# F1 Score on training dataset for Random Forest Classifier: 0.9962457868850697
# Precision Score on test dataset for Random Forest Classifier: 0.902542372881356
# AUC Score on test dataset for Random Forest Classifier: 0.8986528565487308
# F1 Score on test dataset for Random Forest Classifier: 0.8804902493209601

# %% [markdown]
# ## Ada Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline

model_5 = Pipeline(
    steps=[
        ("classifier", AdaBoostClassifier(
            estimator=DecisionTreeClassifier(max_depth=4),
            n_estimators=100,
            learning_rate=0.8
        )),
    ]
)

# %% [markdown]
# ## Training of Ada boost Classifier

# %%
model_5.fit(x_train_tfidf,y_train)
# Out:
# Pipeline(steps=[('classifier',
#                  AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=4),
#                                     learning_rate=0.8, n_estimators=100))])

# %% [markdown]
# ## Evaluation on test data and training data of Ada boost Classifier

# %%
# Evaluate on training dataset
print("Precision Score on training dataset for AdaBoost Classifier: %s" % precision_score(y_train, model_5.predict(x_train_tfidf), average='micro'))
print("AUC Score on training dataset for AdaBoost Classifier: %s" % roc_auc_score(y_train, model_5.predict_proba(x_train_tfidf), multi_class='ovo', average='macro'))
f1_score_train_5 = f1_score(y_train, model_5.predict(x_train_tfidf), average="weighted")
print("F1 Score training dataset for AdaBoost Classifier: %s" % f1_score_train_5)

# Evaluate on test dataset
print("Precision Score on test dataset for AdaBoost Classifier: %s" % precision_score(y_test, model_5.predict(x_test_tfidf), average='micro'))
print("AUC Score on test dataset for AdaBoost Classifier: %s" % roc_auc_score(y_test, model_5.predict_proba(x_test_tfidf), multi_class='ovo', average='macro'))
f1_score_5 = f1_score(y_test, model_5.predict(x_test_tfidf), average="weighted")
print("F1 Score for AdaBoost Classifier: %s" % f1_score_5)
# Out:
# Precision Score on training dataset for AdaBoost Classifier: 0.9271250294325406
# AUC Score on training dataset for AdaBoost Classifier: 0.9694017423343265
# F1 Score training dataset for AdaBoost Classifier: 0.9180920960726309
# Precision Score on test dataset for AdaBoost Classifier: 0.8997175141242938
# AUC Score on test dataset for AdaBoost Classifier: 0.8178540195084879
# F1 Score for AdaBoost Classifier: 0.888064347197309

# %% [markdown]
# Hyperparameter Tunning with Grid Search

# %%
import numpy as np
import pandas as pd
from sklearn import ensemble
from sklearn import metrics
from sklearn import model_selection

def hyperparamtune(classifier, param_grid,metric,verbose_value,cv):
    model=model_selection.GridSearchCV(
            estimator=classifier,
            param_grid=param_grid,
            scoring=metric,
            verbose=verbose_value,            
            cv=cv)

    model.fit(x_train_tfidf,y_train)
    print("Best Score %s" % {model.best_score_})
    print("Best hyperparameter set:")
    best_parameters = model.best_estimator_.get_params()
    for param_name in sorted(param_grid.keys()):
        print(f"\t{param_name}: {best_parameters[param_name]}")
    return model, best_parameters

# %% [markdown]
# Hyperparameter tunning of Logistic Regression

# %%
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import joblib

# Define hyperparameters for Logistic Regression
param_gd = {
    "logisticregression__penalty": ["l2"],
    "logisticregression__C": [0.1, 1.0],
    "logisticregression__tol": [0.0001, 0.001],
    "logisticregression__max_iter": [100],
    "smote__sampling_strategy": ["auto", 0.5, 1.0]  # Adjusting SMOTE's strategy for over-sampling
}

# Create a pipeline with SMOTE and Logistic Regression
pipeline = make_pipeline(
    SMOTE(random_state=42),
    LogisticRegression(random_state=42, max_iter=100)
)

# Hyperparameter tuning with GridSearchCV
grid_search = GridSearchCV(pipeline, param_gd, scoring="accuracy", cv=10, n_jobs=5)
grid_search.fit(x_train_tfidf, y_train)

# Save the best model as model_7
model_7 = grid_search.best_estimator_
best_param_7 = grid_search.best_params_

# Print the best parameters and evaluation
print("Best Parameters for model_7:", best_param_7)
print("Best Accuracy for model_7:", grid_search.best_score_)

# Evaluate on test data
y_pred = model_7.predict(x_test_tfidf)
print("\nClassification Report on Test Data:")
print(classification_report(y_test, y_pred))
# Out:
# Best Parameters for model_7: {'logisticregression__C': 1.0, 'logisticregression__max_iter': 100, 'logisticregression__penalty': 'l2', 'logisticregression__tol': 0.0001, 'smote__sampling_strategy': 'auto'}
# Best Accuracy for model_7: 0.8779145014896418
#
# Classification Report on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.59      0.79      0.68       253
#            1       0.97      0.89      0.93      1837
#            2       0.12      0.32      0.17        34
#
#     accuracy                           0.87      2124
#    macro avg       0.56      0.67      0.59      2124
# weighted avg       0.91      0.87      0.89      2124

# %% [markdown]
# Evaluation of FineTuned Logsitic Regression Classifier

# %%
from sklearn.metrics import precision_score, roc_auc_score, f1_score

# Precision, AUC, and F1 Scores for Training Dataset
print("Precision Score on training dataset for Finetuned Logistic Regression Classifier: %s" %
      precision_score(y_train, model_7.predict(x_train_tfidf), average='micro'))

# Use 'predict_proba' for multiclass AUC without slicing
print("AUC Score on training dataset for Finetuned Logistic Regression Classifier: %s" %
      roc_auc_score(y_train, model_7.predict_proba(x_train_tfidf), multi_class='ovo', average='macro'))

f1_score_train_7 = f1_score(y_train, model_7.predict(x_train_tfidf), average="weighted")
print("F1 Score training dataset for Finetuned Logistic Regression Classifier: %s" % f1_score_train_7)

# Precision, AUC, and F1 Scores for Test Dataset
print("Precision Score on test dataset for Finetuned Logistic Regression Classifier: %s" %
      precision_score(y_test, model_7.predict(x_test_tfidf), average='micro'))

# Use 'predict_proba' for multiclass AUC without slicing
print("AUC Score on test dataset for Finetuned Logistic Regression Classifier: %s" %
      roc_auc_score(y_test, model_7.predict_proba(x_test_tfidf), multi_class='ovo', average='macro'))

f1_score_7 = f1_score(y_test, model_7.predict(x_test_tfidf), average="weighted")
print("F1 Score for Finetuned Logistic Regression Classifier: %s" % f1_score_7)
# Out:
# Precision Score on training dataset for Finetuned Logistic Regression Classifier: 0.9198257593595479
# AUC Score on training dataset for Finetuned Logistic Regression Classifier: 0.9852100673089401
# F1 Score training dataset for Finetuned Logistic Regression Classifier: 0.9274101711165558
# Precision Score on test dataset for Finetuned Logistic Regression Classifier: 0.8728813559322034
# AUC Score on test dataset for Finetuned Logistic Regression Classifier: 0.8608720396074542
# F1 Score for Finetuned Logistic Regression Classifier: 0.8886985277030172

# %% [markdown]
# Hyperparameter Tunning for Random Forest Classifier

# %%
from imblearn.pipeline import make_pipeline
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV  # Randomized Search
from sklearn.metrics import classification_report
import joblib

# Define hyperparameters for model_8 (with reduced grid)
param_gd = {
    "randomforestclassifier__n_estimators": [100, 150],
    "randomforestclassifier__max_depth": [11, 13, 17],
    "randomforestclassifier__criterion": ["gini"],
    "randomforestclassifier__min_samples_split": [3, 7],
    "randomforestclassifier__min_samples_leaf": [3],
    "randomforestclassifier__max_features": ["sqrt"]
}

# Create a pipeline with SMOTE and Random Forest
pipeline = make_pipeline(
    SMOTE(random_state=42),
    RandomForestClassifier(random_state=42)
)

# Use RandomizedSearchCV for faster hyperparameter search
random_search = RandomizedSearchCV(pipeline, param_gd, scoring="accuracy", cv=5, n_jobs=-1, n_iter=10, random_state=42)
random_search.fit(x_train_tfidf, y_train)

# Save the best model as model_8
model_8 = random_search.best_estimator_
best_param_8 = random_search.best_params_

# Print the best parameters and evaluation
print("Best Parameters for model_8:", best_param_8)
print("Best Accuracy for model_8:", random_search.best_score_)

# Evaluate on test data
y_pred = model_8.predict(x_test_tfidf)
print("\nClassification Report on Test Data:")
print(classification_report(y_test, y_pred))

# Save the final model
#joblib.dump(model_8, r"C:\Users\Edna\Documents\GitHub\Haile_Resort_Sentiment_Analysis\models\model_8.pkl")
# Out:
# Best Parameters for model_8: {'randomforestclassifier__n_estimators': 100, 'randomforestclassifier__min_samples_split': 3, 'randomforestclassifier__min_samples_leaf': 3, 'randomforestclassifier__max_features': 'sqrt', 'randomforestclassifier__max_depth': 17, 'randomforestclassifier__criterion': 'gini'}
# Best Accuracy for model_8: 0.8591951477034575
#
# Classification Report on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.68      0.55      0.61       253
#            1       0.94      0.90      0.92      1837
#            2       0.06      0.29      0.10        34
#
#     accuracy                           0.85      2124
#    macro avg       0.56      0.58      0.54      2124
# weighted avg       0.90      0.85      0.87      2124

# %% [markdown]
# Evaluation of Finetuned Random Forest Classifier

# %%
from sklearn.metrics import precision_score, roc_auc_score, f1_score

# Precision, AUC, and F1 Score on the training dataset for the Finetuned Random Forest Classifier
print("Precision Score on training dataset for Finetuned Random Forest Classifier: %s" % precision_score(y_train, model_8.predict(x_train_tfidf), average='micro'))
print("AUC Score on training dataset for Finetuned Random Forest Classifier: %s" % roc_auc_score(y_train, model_8.predict_proba(x_train_tfidf), multi_class='ovo', average='macro'))
f1_score_train_8 = f1_score(y_train, model_8.predict(x_train_tfidf), average="weighted")
print("F1 Score training dataset for Finetuned Random Forest Classifier: %s" % f1_score_train_8)

# Precision, AUC, and F1 Score on the test dataset for the Finetuned Random Forest Classifier
print("Precision Score on test dataset for Finetuned Random Forest Classifier: %s" % precision_score(y_test, model_8.predict(x_test_tfidf), average='micro'))
print("AUC Score on test dataset for Finetuned Random Forest Classifier: %s" % roc_auc_score(y_test, model_8.predict_proba(x_test_tfidf), multi_class='ovo', average='macro'))
f1_score_8 = f1_score(y_test, model_8.predict(x_test_tfidf), average="weighted")
print("F1 Score for Finetuned Random Forest Classifier: %s" % f1_score_8)
# Out:
# Precision Score on training dataset for Finetuned Random Forest Classifier: 0.9170002354603249
# AUC Score on training dataset for Finetuned Random Forest Classifier: 0.9862804346965436
# F1 Score training dataset for Finetuned Random Forest Classifier: 0.9336271095917107
# Precision Score on test dataset for Finetuned Random Forest Classifier: 0.8512241054613936
# AUC Score on test dataset for Finetuned Random Forest Classifier: 0.8202108391278992
# F1 Score for Finetuned Random Forest Classifier: 0.8726948141214694

# %%
import joblib  # or you can use 'import pickle'
import os

# Specify the path where the model will be saved
save_path = r"C:\Users\Edna\Documents\GitHub\Haile_Resort_Sentiment_Analysis\models\Model.joblib"

# List of models and corresponding F1 scores
models = [model_1, model_2, model_3, model_4, model_5, model_7, model_8]
f1_scores = [f1_score_1, f1_score_2, f1_score_3, f1_score_4, f1_score_5, f1_score_7, f1_score_8]

# Find the model with the highest F1 score
best_f1_score = max(f1_scores)
best_model_index = f1_scores.index(best_f1_score)
best_model = models[best_model_index]

# Model names
model_names = [
    "Logistic Regression",
    "Overfit Decision Tree",
    "Decision Tree",
    "Random Forest",
    "Adaboost Classifier",
    "Finetuned Logistic Regression Classifier",
    "Finetuned Random Forest Classifier"
]

# Print the best model and its F1 score
print(f"{model_names[best_model_index]} is providing the best F1 score: {best_f1_score}")

# Save the best model to the specified path
joblib.dump(best_model, save_path)
print(f"Best model saved at: {save_path}")
# Out:
# Logistic Regression is providing the best F1 score: 0.9099391274977436
# Best model saved at: C:\Users\Edna\Documents\GitHub\Haile_Resort_Sentiment_Analysis\models\Model.joblib

# %% [markdown]
# Load the Saved Model

# %%
import joblib

# Load the saved model
model_path = r"C:\Users\Edna\Documents\GitHub\Haile_Resort_Sentiment_Analysis\models\Model.joblib"
best_model = joblib.load(model_path)

print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Make predictions with the loaded model

# %%
# Make predictions on the test set
y_pred = best_model.predict(x_test_tfidf)

print("Predictions on test data:", y_pred)
# Out:
# Predictions on test data: [1 1 0 ... 1 1 1]

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, roc_auc_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Calculate F1 score
f1 = f1_score(y_test, y_pred, average="weighted")
print(f"F1 Score: {f1}")

# Calculate Precision score
precision = precision_score(y_test, y_pred, average="micro")
print(f"Precision Score: {precision}")

# If you want to use AUC score (use only for multiclass classification if applicable)
# Ensure predict_proba() works for your classifier
try:
    auc = roc_auc_score(y_test, best_model.predict_proba(x_test_tfidf), multi_class='ovo', average='macro')
    print(f"AUC Score: {auc}")
except Exception as e:
    print("AUC calculation error:", e)
# Out:
# Accuracy: 0.9199623352165726
# F1 Score: 0.9099391274977436
# Precision Score: 0.9199623352165726
# AUC Score: 0.8542628024161353

# %% [markdown]
# Make Predictions on New Data

# %%
new_reviews = ['I had a fantastic experience. The food was great, and the location was perfect. Will be coming back next time!',
               'The hotel was noisy and uncomfortable.',
               "The service was excellent, and the room was very comfortable. I had a wonderful time and would definitely return."
               
    
]
# Transform the new reviews using the same vectorizer
new_reviews_tfidf = tfidfvect.transform(new_reviews).toarray()

# Make predictions
predictions = best_model.predict(new_reviews_tfidf)

print("Predictions on new reviews:", predictions)
# Out:
# Predictions on new reviews: [1 0 1]

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict on test data
y_pred = model_7.predict(x_test_tfidf)

# Evaluate F1 Score for different averaging methods
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print(f"Micro F1 Score: {f1_micro}")
print(f"Macro F1 Score: {f1_macro}")
print(f"Weighted F1 Score: {f1_weighted}")
# Out:
# Micro F1 Score: 0.8728813559322034
# Macro F1 Score: 0.5939226854405426
# Weighted F1 Score: 0.8886985277030172

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
import seaborn as sns
import matplotlib.pyplot as plt

# Define Logistic Regression model
log_reg = LogisticRegression(random_state=42)

# SMOTE instance
smote = SMOTE(random_state=42)

# Create the pipeline with SMOTE and Logistic Regression
pipeline = make_pipeline(smote, log_reg)

# Confusion Matrix visualization
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Neutral", "Positive"], yticklabels=["Negative", "Neutral", "Positive"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %% [markdown]
# Model 2

# %%
import joblib

# Assuming model_8 is your fine-tuned model
joblib.dump(model_8, 'C:/Users/Edna/Documents/GitHub/Haile_Resort_Sentiment_Analysis/models/model_8.pkl')
print("Model 8 has been saved successfully.")
# Out:
# Model 8 has been saved successfully.

# %%
# To load the saved model for use later
model_8_loaded = joblib.load('C:/Users/Edna/Documents/GitHub/Haile_Resort_Sentiment_Analysis/models/model_8.pkl')

# Now you can use model_8_loaded to make predictions
predictions = model_8_loaded.predict(x_test_tfidf)
print("Predictions on test set:", predictions)
# Out:
# Predictions on test set: [1 1 2 ... 1 1 1]

# %%
from sklearn.metrics import f1_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict on test data
y_pred = model_8.predict(x_test_tfidf)

# Evaluate F1 Score for different averaging methods
f1_micro = f1_score(y_test, y_pred, average='micro')
f1_macro = f1_score(y_test, y_pred, average='macro')
f1_weighted = f1_score(y_test, y_pred, average='weighted')

print(f"Micro F1 Score: {f1_micro}")
print(f"Macro F1 Score: {f1_macro}")
print(f"Weighted F1 Score: {f1_weighted}")
# Out:
# Micro F1 Score: 0.8512241054613936
# Macro F1 Score: 0.54462152201806
# Weighted F1 Score: 0.8726948141214694

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, roc_auc_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Calculate F1 score
f1 = f1_score(y_test, y_pred, average="weighted")
print(f"F1 Score: {f1}")

# Calculate Precision score
precision = precision_score(y_test, y_pred, average="micro")
print(f"Precision Score: {precision}")

# If you want to use AUC score (use only for multiclass classification if applicable)
# Ensure predict_proba() works for your classifier
try:
    auc = roc_auc_score(y_test, model_8.predict_proba(x_test_tfidf), multi_class='ovo', average='macro')
    print(f"AUC Score: {auc}")
except Exception as e:
    print("AUC calculation error:", e)
# Out:
# Accuracy: 0.8728813559322034
# F1 Score: 0.8886985277030172
# Precision Score: 0.8728813559322034
# AUC Score: 0.8202108391278992

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming best_model is your trained model and x_test_tfidf and y_test are your test data.
y_pred = model_8.predict(x_test_tfidf)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive", "Neutral"], yticklabels=["Negative", "Positive", "Neutral"])
plt.title("Confusion Matrix for model_8")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
